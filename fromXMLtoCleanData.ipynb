# %%
import xml.etree.ElementTree as ET
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
archivo_xml = 'exportacion.xml'  

tree = ET.parse(archivo_xml)
root = tree.getroot()

# %%
#We select the different types of records provided by the health app.
unique_type = set()
for record in root.findall(".//Record[@type]"):  
    type = record.get('type')  
    unique_type.add(type)
unique_type
# Out:
# {'HKCategoryTypeIdentifierHeadphoneAudioExposureEvent',
#  'HKCategoryTypeIdentifierSleepAnalysis',
#  'HKDataTypeSleepDurationGoal',
#  'HKQuantityTypeIdentifierActiveEnergyBurned',
#  'HKQuantityTypeIdentifierAppleWalkingSteadiness',
#  'HKQuantityTypeIdentifierBasalEnergyBurned',
#  'HKQuantityTypeIdentifierBodyMass',
#  'HKQuantityTypeIdentifierDistanceWalkingRunning',
#  'HKQuantityTypeIdentifierFlightsClimbed',
#  'HKQuantityTypeIdentifierHeadphoneAudioExposure',
#  'HKQuantityTypeIdentifierHeight',
#  'HKQuantityTypeIdentifierStepCount',
#  'HKQuantityTypeIdentifierWalkingAsymmetryPercentage',
#  'HKQuantityTypeIdentifierWalkingDoubleSupportPercentage',
#  'HKQuantityTypeIdentifierWalkingSpeed',
#  'HKQuantityTypeIdentifierWalkingStepLength'}

# %%
# transform the records into a df 
records_data = []
for record in root.findall(".//Record[@type='HKQuantityTypeIdentifierStepCount']"):
    data = {
        'type': record.get('type'),
        'unit': record.get('unit'),
        'value': record.get('value'),
        'startDate': record.get('startDate'),
        'endDate': record.get('endDate')
    }
    records_data.append(data)

df = pd.DataFrame(records_data)
# Out:
#                                      type   unit value  \
# 0       HKQuantityTypeIdentifierStepCount  count   127
# 1       HKQuantityTypeIdentifierStepCount  count    42
# 2       HKQuantityTypeIdentifierStepCount  count    69
# 3       HKQuantityTypeIdentifierStepCount  count   137
# 4       HKQuantityTypeIdentifierStepCount  count   168
# ...                                   ...    ...   ...
# 113454  HKQuantityTypeIdentifierStepCount  count    45
# 113455  HKQuantityTypeIdentifierStepCount  count    97
# 113456  HKQuantityTypeIdentifierStepCount  count   102
# 113457  HKQuantityTypeIdentifierStepCount  count    53
# 113458  HKQuantityTypeIdentifierStepCount  count    24
#
#                         startDate                    endDate
# 0       2018-12-29 19:32:27 +0100  2018-12-29 19:36:41 +0100
# 1       2018-12-29 20:00:58 +0100  2018-12-29 20:05:27 +0100
# 2       2018-12-29 20:10:57 +0100  2018-12-29 20:20:54 +0100
# 3       2018-12-29 20:20:57 +0100  2018-12-29 20:30:56 +0100
# 4       2018-12-29 20:30:56 +0100  2018-12-29 20:39:56 +0100
# ...                           ...                        ...
# 113454  2024-02-25 15:09:40 +0100  2024-02-25 15:11:07 +0100
# 113455  2024-02-25 15:35:33 +0100  2024-02-25 15:37:17 +0100
# 113456  2024-02-25 16:57:46 +0100  2024-02-25 17:07:45 +0100
# 113457  2024-02-25 17:07:45 +0100  2024-02-25 17:08:51 +0100
# 113458  2024-02-25 17:55:07 +0100  2024-02-25 17:58:46 +0100
#
# [113459 rows x 5 columns]

# %% [markdown]
# # Convert all records to a df

# %%
records_data = []
for uniqueType in unique_type:
    for record in root.findall(f".//Record[@type='{uniqueType}']"):
        data = {
            'type': record.get('type'),
            'unit': record.get('unit'),
            'value': record.get('value'),
            'startDate': record.get('startDate'),
            'endDate': record.get('endDate')
        }
        records_data.append(data)

df = pd.DataFrame(records_data)

# %% [markdown]
# # I perform a small EDA and delete the variables that do not contain reported values

# %%
df.shape
# Out:
# (492078, 5)

# %%
df[df["unit"].notna()]
# Out:
#                                                   type    unit    value  \
# 4280    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  61.3529
# 4281    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  76.6343
# 4282    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  79.0971
# 4283    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  81.8957
# 4284    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  92.9585
# ...                                                ...     ...      ...
# 491774            HKQuantityTypeIdentifierWalkingSpeed   km/hr    4.572
# 491775            HKQuantityTypeIdentifierWalkingSpeed   km/hr    4.104
# 491776            HKQuantityTypeIdentifierWalkingSpeed   km/hr      4.5
# 491777            HKQuantityTypeIdentifierWalkingSpeed   km/hr    3.996
# 491778            HKQuantityTypeIdentifierWalkingSpeed   km/hr      4.5
#
#                         startDate                    endDate
# 4280    2020-09-20 19:10:45 +0100  2020-09-20 19:14:56 +0100
# 4281    2020-09-29 17:49:21 +0100  2020-09-29 17:55:52 +0100
# 4282    2020-09-29 18:45:04 +0100  2020-09-29 18:45:31 +0100
# 4283    2020-09-29 18:54:34 +0100  2020-09-29 18:58:47 +0100
# 4284    2020-10-06 14:59:39 +0100  2020-10-06 15:00:15 +0100
# ...                           ...                        ...
# 491774  2024-02-25 14:24:47 +0100  2024-02-25 14:24:50 +0100
# 491775  2024-02-25 15:36:05 +0100  2024-02-25 15:36:07 +0100
# 491776  2024-02-25 15:36:53 +0100  2024-02-25 15:36:56 +0100
# 491777  2024-02-25 15:37:08 +0100  2024-02-25 15:37:15 +0100
# 491778  2024-02-25 17:07:42 +0100  2024-02-25 17:07:44 +0100
#
# [487499 rows x 5 columns]

# %%
df[df["unit"].notna()].unit.value_counts(dropna=False)
# Out:
# count     124579
# km        113184
# %          54869
# km/hr      46102
# cm         46083
# dBASPL     45050
# kcal       36714
# Cal        20914
# hr             3
# kg             1
# Name: unit, dtype: int64

# %%
df[df["unit"].isna()].type.value_counts(dropna=False)
# Out:
# HKCategoryTypeIdentifierSleepAnalysis                  4280
# HKCategoryTypeIdentifierHeadphoneAudioExposureEvent     299
# Name: type, dtype: int64

# %%
df[df["type"]=="HKCategoryTypeIdentifierHeadphoneAudioExposureEvent"].value.value_counts()
# Out:
# HKCategoryValueHeadphoneAudioExposureEventSevenDayLimit    299
# Name: value, dtype: int64

# %%
df[df["type"]=="HKCategoryTypeIdentifierSleepAnalysis"].value.value_counts()
# Out:
# HKCategoryValueSleepAnalysisInBed    4280
# Name: value, dtype: int64

# %%
df_values = df[df["unit"].notna()]

# %%
df_values
# Out:
#                                                   type    unit    value  \
# 4280    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  61.3529
# 4281    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  76.6343
# 4282    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  79.0971
# 4283    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  81.8957
# 4284    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  92.9585
# ...                                                ...     ...      ...
# 491774            HKQuantityTypeIdentifierWalkingSpeed   km/hr    4.572
# 491775            HKQuantityTypeIdentifierWalkingSpeed   km/hr    4.104
# 491776            HKQuantityTypeIdentifierWalkingSpeed   km/hr      4.5
# 491777            HKQuantityTypeIdentifierWalkingSpeed   km/hr    3.996
# 491778            HKQuantityTypeIdentifierWalkingSpeed   km/hr      4.5
#
#                         startDate                    endDate
# 4280    2020-09-20 19:10:45 +0100  2020-09-20 19:14:56 +0100
# 4281    2020-09-29 17:49:21 +0100  2020-09-29 17:55:52 +0100
# 4282    2020-09-29 18:45:04 +0100  2020-09-29 18:45:31 +0100
# 4283    2020-09-29 18:54:34 +0100  2020-09-29 18:58:47 +0100
# 4284    2020-10-06 14:59:39 +0100  2020-10-06 15:00:15 +0100
# ...                           ...                        ...
# 491774  2024-02-25 14:24:47 +0100  2024-02-25 14:24:50 +0100
# 491775  2024-02-25 15:36:05 +0100  2024-02-25 15:36:07 +0100
# 491776  2024-02-25 15:36:53 +0100  2024-02-25 15:36:56 +0100
# 491777  2024-02-25 15:37:08 +0100  2024-02-25 15:37:15 +0100
# 491778  2024-02-25 17:07:42 +0100  2024-02-25 17:07:44 +0100
#
# [487499 rows x 5 columns]

# %%
df_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 487499 entries, 4280 to 491778
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   type       487499 non-null  object
#  1   unit       487499 non-null  object
#  2   value      487499 non-null  object
#  3   startDate  487499 non-null  object
#  4   endDate    487499 non-null  object
# dtypes: object(5)
# memory usage: 22.3+ MB

# %%
df_values['startDate'] = pd.to_datetime(df_values['startDate'])
df_values['endDate'] = pd.to_datetime(df_values['endDate'])
# Out:
# /var/folders/vp/j4bs4hm57djdxqm9dxn37kt00000gn/T/ipykernel_1297/2959461337.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_values['startDate'] = pd.to_datetime(df_values['startDate'])
# /var/folders/vp/j4bs4hm57djdxqm9dxn37kt00000gn/T/ipykernel_1297/2959461337.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_values['endDate'] = pd.to_datetime(df_values['endDate'])

# %%
df_values['startDate_date'] = df_values['startDate'].dt.date
df_values['endDate_date'] = df_values['endDate'].dt.date
df_values['startDate_time'] = df_values['startDate'].dt.time
df_values['endDate_time'] = df_values['endDate'].dt.time

# %%
del(df_values["startDate"])
del(df_values["endDate"])

# %%
df_values
# Out:
#                                                   type    unit    value  \
# 4280    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  61.3529
# 4281    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  76.6343
# 4282    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  79.0971
# 4283    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  81.8957
# 4284    HKQuantityTypeIdentifierHeadphoneAudioExposure  dBASPL  92.9585
# ...                                                ...     ...      ...
# 491774            HKQuantityTypeIdentifierWalkingSpeed   km/hr    4.572
# 491775            HKQuantityTypeIdentifierWalkingSpeed   km/hr    4.104
# 491776            HKQuantityTypeIdentifierWalkingSpeed   km/hr      4.5
# 491777            HKQuantityTypeIdentifierWalkingSpeed   km/hr    3.996
# 491778            HKQuantityTypeIdentifierWalkingSpeed   km/hr      4.5
#
#        startDate_date endDate_date startDate_time endDate_time
# 4280       2020-09-20   2020-09-20       19:10:45     19:14:56
# 4281       2020-09-29   2020-09-29       17:49:21     17:55:52
# 4282       2020-09-29   2020-09-29       18:45:04     18:45:31
# 4283       2020-09-29   2020-09-29       18:54:34     18:58:47
# 4284       2020-10-06   2020-10-06       14:59:39     15:00:15
# ...               ...          ...            ...          ...
# 491774     2024-02-25   2024-02-25       14:24:47     14:24:50
# 491775     2024-02-25   2024-02-25       15:36:05     15:36:07
# 491776     2024-02-25   2024-02-25       15:36:53     15:36:56
# 491777     2024-02-25   2024-02-25       15:37:08     15:37:15
# 491778     2024-02-25   2024-02-25       17:07:42     17:07:44
#
# [487499 rows x 7 columns]
